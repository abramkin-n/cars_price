# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Загрузка-и-подготовка-данных" data-toc-modified-id="Загрузка-и-подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Загрузка и подготовка данных</a></span></li><li><span><a href="#Знакомство-с-данными" data-toc-modified-id="Знакомство-с-данными-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Знакомство с данными</a></span></li><li><span><a href="#Обработка-пропусков" data-toc-modified-id="Обработка-пропусков-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Обработка пропусков</a></span></li><li><span><a href="#Рассмотрение-признаков" data-toc-modified-id="Рассмотрение-признаков-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Рассмотрение признаков</a></span><ul class="toc-item"><li><span><a href="#Рассмотим-данные-столбца-saledate-(дата-продажи-автомобиля):" data-toc-modified-id="Рассмотим-данные-столбца-saledate-(дата-продажи-автомобиля):-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Рассмотим данные столбца <code>saledate</code> (дата продажи автомобиля):</a></span></li><li><span><a href="#Рассмотим-данные-столбца-year-(год-выпуска-автомобиля):" data-toc-modified-id="Рассмотим-данные-столбца-year-(год-выпуска-автомобиля):-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Рассмотим данные столбца <code>year</code> (год выпуска автомобиля):</a></span></li><li><span><a href="#Рассмотим-данные-столбца-make-(марка-автомобиля):" data-toc-modified-id="Рассмотим-данные-столбца-make-(марка-автомобиля):-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Рассмотим данные столбца <code>make</code> (марка автомобиля):</a></span></li><li><span><a href="#Рассмотим-данные-столбца-model-(модель-автомобиля):" data-toc-modified-id="Рассмотим-данные-столбца-model-(модель-автомобиля):-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Рассмотим данные столбца <code>model</code> (модель автомобиля):</a></span></li><li><span><a href="#Рассмотим-данные-столбца-body-(тип-кузова-транспортного-средства):" data-toc-modified-id="Рассмотим-данные-столбца-body-(тип-кузова-транспортного-средства):-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Рассмотим данные столбца <code>body</code> (тип кузова транспортного средства):</a></span></li><li><span><a href="#Рассмотим-данные-столбца-transmission-(коробка-передач):" data-toc-modified-id="Рассмотим-данные-столбца-transmission-(коробка-передач):-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Рассмотим данные столбца <code>transmission</code> (коробка передач):</a></span></li><li><span><a href="#Рассмотим-данные-столбца-state-(название-штата):" data-toc-modified-id="Рассмотим-данные-столбца-state-(название-штата):-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Рассмотим данные столбца <code>state</code> (название штата):</a></span></li><li><span><a href="#Рассмотим-данные-столбца-condition-(cостояние-автомобилей-на-момент-аукциона):" data-toc-modified-id="Рассмотим-данные-столбца-condition-(cостояние-автомобилей-на-момент-аукциона):-4.8"><span class="toc-item-num">4.8&nbsp;&nbsp;</span>Рассмотим данные столбца <code>condition</code> (cостояние автомобилей на момент аукциона):</a></span></li><li><span><a href="#Рассмотим-данные-столбца-odometer-(расстояние,-пройденное-автомобилем-с-момента-выпуска):" data-toc-modified-id="Рассмотим-данные-столбца-odometer-(расстояние,-пройденное-автомобилем-с-момента-выпуска):-4.9"><span class="toc-item-num">4.9&nbsp;&nbsp;</span>Рассмотим данные столбца <code>odometer</code> (расстояние, пройденное автомобилем с момента выпуска):</a></span></li><li><span><a href="#Рассмотим-данные-столбца-color-(цвет-кузова-автомобиля):" data-toc-modified-id="Рассмотим-данные-столбца-color-(цвет-кузова-автомобиля):-4.10"><span class="toc-item-num">4.10&nbsp;&nbsp;</span>Рассмотим данные столбца <code>color</code> (цвет кузова автомобиля):</a></span></li><li><span><a href="#Рассмотим-данные-столбца-interior-(цвет-салона-автомобиля):" data-toc-modified-id="Рассмотим-данные-столбца-interior-(цвет-салона-автомобиля):-4.11"><span class="toc-item-num">4.11&nbsp;&nbsp;</span>Рассмотим данные столбца <code>interior</code> (цвет салона автомобиля):</a></span></li><li><span><a href="#Рассмотим-данные-столбца-sellingprice-(цена,-по-которой-автомобиль-был-продан-на-аукционе):" data-toc-modified-id="Рассмотим-данные-столбца-sellingprice-(цена,-по-которой-автомобиль-был-продан-на-аукционе):-4.12"><span class="toc-item-num">4.12&nbsp;&nbsp;</span>Рассмотим данные столбца <code>sellingprice</code> (цена, по которой автомобиль был продан на аукционе):</a></span></li></ul></li><li><span><a href="#Создание-новых-признаков" data-toc-modified-id="Создание-новых-признаков-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Создание новых признаков</a></span></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span></li><li><span><a href="#Матрица-корреляции" data-toc-modified-id="Матрица-корреляции-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Матрица корреляции</a></span></li><li><span><a href="#Оптимизация-используемой-памяти" data-toc-modified-id="Оптимизация-используемой-памяти-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Оптимизация используемой памяти</a></span></li><li><span><a href="#Обучение-моделей" data-toc-modified-id="Обучение-моделей-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Обучение моделей</a></span><ul class="toc-item"><li><span><a href="#Построим-модель-CatBoostRegressor:" data-toc-modified-id="Построим-модель-CatBoostRegressor:-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>Построим модель <code>CatBoostRegressor</code>:</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Описание проекта:

# %% [markdown]
# ### Загрузка и подготовка данных

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import warnings
import time
from datetime import datetime
from phik import phik_matrix

from sklearn.model_selection import (train_test_split, 
                                     GridSearchCV)

from catboost import CatBoostRegressor
from lightgbm import LGBMRegressor
from sklearn.dummy import DummyRegressor

#from sklearn.ensemble import RandomForestClassifier
#from sklearn.preprocessing import (OneHotEncoder,
                                   #StandardScaler)
    
from sklearn.metrics import confusion_matrix

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
#try:
df = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')
sample_submission = pd.read_csv('sample_submission.csv')
    
# except:
#     contract = pd.read_csv('kaggle competitions download -c used-cars-price-prediction-22ds')
#     personal = pd.read_csv('https://code.s3.yandex.net/datasets/personal_new.csv')
#     internet = pd.read_csv('https://code.s3.yandex.net/datasets/internet_new.csv')

# %% [markdown]
# ### Знакомство с данными

# %%
def info(data):
    display(data.head())
    display(data.info(memory_usage=True))
    print(20 * '-' + 'Описание данных' + 20 * '-')
    display(data.describe(include='all'))
    print(20 * '-' + 'Количество пропусков' + 20 * '-')
    display(data.isna().sum())
    print(20 * '-' + 'Количество дубликатов' + 20 * '-')
    display(data.duplicated().sum())

# %%
info(df)
# Out:
#    year    make   model    trim   body transmission                vin state  \
# 0  2011    Ford    Edge     SEL    suv    automatic  2fmdk3jc4bba41556    md
# 1  2014    Ford  Fusion      SE  Sedan    automatic  3fa6p0h75er208976    mo
# 2  2012  Nissan  Sentra  2.0 SL  sedan    automatic  3n1ab6ap4cl698412    nj
# 3  2003  HUMMER      H2    Base    suv    automatic  5grgn23u93h101360    tx
# 4  2007    Ford  Fusion     SEL  Sedan    automatic  3fahp08z17r268380    md
#
#    condition  odometer  color interior                      seller  \
# 0        4.2  111041.0  black    black          santander consumer
# 1        3.5   31034.0  black    black       ars/avis budget group
# 2        2.2   35619.0  black    black          nissan-infiniti lt
# 3        2.8  131301.0   gold    beige  wichita falls ford lin inc
# 4        2.0  127709.0  black    black                purple heart
#
#    sellingprice                                 saledate
# 0         12500  Tue Jun 02 2015 02:30:00 GMT-0700 (PDT)
# 1         14500  Wed Feb 25 2015 02:00:00 GMT-0800 (PST)
# 2          9100  Wed Jun 10 2015 02:30:00 GMT-0700 (PDT)
# 3         13300  Wed Jun 17 2015 03:00:00 GMT-0700 (PDT)
# 4          1300  Tue Feb 03 2015 04:00:00 GMT-0800 (PST)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440236 entries, 0 to 440235
# Data columns (total 15 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   year          440236 non-null  int64
#  1   make          432193 non-null  object
#  2   model         432113 non-null  object
#  3   trim          431899 non-null  object
#  4   body          429843 non-null  object
#  5   transmission  388775 non-null  object
#  6   vin           440236 non-null  object
#  7   state         440236 non-null  object
#  8   condition     430831 non-null  float64
#  9   odometer      440167 non-null  float64
#  10  color         439650 non-null  object
#  11  interior      439650 non-null  object
#  12  seller        440236 non-null  object
#  13  sellingprice  440236 non-null  int64
#  14  saledate      440236 non-null  object
# dtypes: float64(2), int64(2), object(11)
# memory usage: 50.4+ MB
# None
# --------------------Описание данных--------------------
#                  year    make   model    trim    body transmission  \
# count   440236.000000  432193  432113  431899  429843       388775
# unique            NaN      92     959    1922      85            2
# top               NaN    Ford  Altima    Base   Sedan    automatic
# freq              NaN   73708   15454   43853  157639       375061
# mean      2010.040101     NaN     NaN     NaN     NaN          NaN
# std          3.977945     NaN     NaN     NaN     NaN          NaN
# min       1982.000000     NaN     NaN     NaN     NaN          NaN
# 25%       2007.000000     NaN     NaN     NaN     NaN          NaN
# 50%       2012.000000     NaN     NaN     NaN     NaN          NaN
# 75%       2013.000000     NaN     NaN     NaN     NaN          NaN
# max       2015.000000     NaN     NaN     NaN     NaN          NaN
#
#                       vin   state      condition       odometer   color  \
# count              440236  440236  430831.000000  440167.000000  439650
# unique             440236      38            NaN            NaN      20
# top     2fmdk3jc4bba41556      fl            NaN            NaN   black
# freq                    1   65618            NaN            NaN   87115
# mean                  NaN     NaN       3.425077   68344.421604     NaN
# std                   NaN     NaN       0.949973   53542.203908     NaN
# min                   NaN     NaN       1.000000       1.000000     NaN
# 25%                   NaN     NaN       2.700000   28258.000000     NaN
# 50%                   NaN     NaN       3.600000   52098.000000     NaN
# 75%                   NaN     NaN       4.200000   99272.000000     NaN
# max                   NaN     NaN       5.000000  999999.000000     NaN
#
#        interior              seller   sellingprice  \
# count    439650              440236  440236.000000
# unique       17               13025            NaN
# top       black  nissan-infiniti lt            NaN
# freq     192442               15823            NaN
# mean        NaN                 NaN   13592.209588
# std         NaN                 NaN    9751.479098
# min         NaN                 NaN       1.000000
# 25%         NaN                 NaN    6900.000000
# 50%         NaN                 NaN   12100.000000
# 75%         NaN                 NaN   18200.000000
# max         NaN                 NaN  230000.000000
#
#                                        saledate
# count                                    440236
# unique                                     3597
# top     Tue Feb 10 2015 01:30:00 GMT-0800 (PST)
# freq                                       4209
# mean                                        NaN
# std                                         NaN
# min                                         NaN
# 25%                                         NaN
# 50%                                         NaN
# 75%                                         NaN
# max                                         NaN
# --------------------Количество пропусков--------------------
# year                0
# make             8043
# model            8123
# trim             8337
# body            10393
# transmission    51461
# vin                 0
# state               0
# condition        9405
# odometer           69
# color             586
# interior          586
# seller              0
# sellingprice        0
# saledate            0
# dtype: int64
# --------------------Количество дубликатов--------------------
# 0

# %%
sns.set(style='ticks')
sns.pairplot(df, corner=True)
plt.suptitle('Диаграмма рассеивания', y=1.02)
plt.show()

# %% [markdown]
# На диаграмме видно, что в данных присутсвуют выбросы, очевидная линейная зависимость признаков не наблюдается.

# %% [markdown]
# ### Обработка пропусков

# %% [markdown]
# **Пропуски `make`, `model`, `trim`:**

# %%
df[df['make'].isna() & df['model'].isna() & df['trim'].isna()]['year'].count()
# Out:
# 8043

# %% [markdown]
# Видим, что пропуски в марке, модели и версии автомобиля находятся в одних и тех же строках, удалим их. Также, учитывая, что в модели и версии автомобиля останется маленькое количество пропусков, их тоже удалим.

# %% [markdown]
# **Пропуски `condition` и `odometer`:**

# %% [markdown]
# Данные пропуски важны и их заполнение может повлиять на модель, поэтому мы их удалим.

# %%
def drop_na(df, columns):
    df.dropna(subset=columns, inplace=True)

drop_na(df, ['make', 'model', 'trim', 'condition', 'odometer'])

# %%
df.isna().sum()
# Out:
# year                0
# make                0
# model               0
# trim                0
# body             1699
# transmission    48544
# vin                 0
# state               0
# condition           0
# odometer            0
# color             492
# interior          492
# seller              0
# sellingprice        0
# saledate            0
# dtype: int64

# %% [markdown]
# **Пропуски `color` и `interior`:**

# %%
df['color'].unique()
# Out:
# array(['black', 'gold', 'silver', 'blue', 'white', 'gray', '—', 'red',
#        'brown', 'green', 'beige', nan, 'off-white', 'yellow', 'burgundy',
#        'orange', 'charcoal', 'purple', 'turquoise', 'lime', 'pink'],
#       dtype=object)

# %%
df['interior'].unique()
# Out:
# array(['black', 'beige', 'gray', 'tan', 'brown', '—', 'off-white', nan,
#        'blue', 'white', 'silver', 'red', 'green', 'gold', 'purple',
#        'orange', 'burgundy', 'yellow'], dtype=object)

# %%
# количетсво '-' в color и interior:
print(df.query('color =="—"')['year'].count(),
df.query('interior =="—"')['year'].count())
# Out:
# 19307 9066

# %% [markdown]
# В цвете кузова (`color`) присутсвует `-` в количестве 19307 и 586 пропуска, заменим эти данные на `unknown`. </br>
# В цвете салона (`interior`) присутсвует `-` в количестве 9066 и 586 пропуска, заменим эти данные на `unknown`

# %%
def fill_color_interior(df, columns, replace_value='—', 
                        fill_value='unknown'):
    for column in columns:
        df[column] = df[column].replace(replace_value, np.nan)
        df[column] = df[column].fillna(fill_value)
        
fill_color_interior(df, columns=['color', 'interior'])

# проверка
print('Количество пропусков в цвете кузова:', df['color'].isna().sum()) 
print('Количество пропусков в цвете интерьера:', df['interior'].isna().sum())
# Out:
# Количество пропусков в цвете кузова: 0
# Количество пропусков в цвете интерьера: 0

# %% [markdown]
# **Заменили не определенные значения и пропуски цвета кузова и салона на unknown в количестве 19893 и 9652 соответсвенно.**

# %% [markdown]
# **Пропуски `body` и `transmission` будут заполнены модой после обработки признаков `make` и `model`**

# %% [markdown]
# ### Рассмотрение признаков

# %% [markdown]
# #### Рассмотим данные столбца `saledate` (дата продажи автомобиля):

# %%
def upgrade_saledate(df):
    df['saledate'] = pd.to_datetime(df['saledate'], utc=True)
    
upgrade_saledate(df)

# %%
df['saledate'].max(), df['saledate'].min()
# Out:
# (Timestamp('2015-07-20 19:30:00+0000', tz='UTC'),
#  Timestamp('2014-01-01 01:15:00+0000', tz='UTC'))

# %%
df['saledate'].max() - df['saledate'].min()
# Out:
# Timedelta('565 days 18:15:00')

# %% [markdown]
# **Данные представлены за 558 дней ~ 1.5 года. </br>
# Первая дата продажи - 01.01.2014. </br>
# Последняя дата продажи - 14.07.2015.**

# %% [markdown]
# #### Рассмотим данные столбца `year` (год выпуска автомобиля):

# %%
# создадим новый признак "количество лет" автомобилю:
def year_count(df):
    
    shape = df.shape[0]
    
    df['year_sale'] = df['saledate'].dt.year
    df['year_count'] = df['year_sale'] - df['year']
    
    print('Уникальные значения:',df['year_count'].unique())
    
    # количество, где год = -1:
    wrong_year = df.query('year_count == -1')['year'].count()
    print('Количество значений, где год = -1:', wrong_year)
    
    # удаление неправильных значений:
    df.drop(df.query('year_count == -1').index, inplace=True)
    
    # проверка:
    print('Удаление произведено:', shape - wrong_year == df.shape[0])
    
year_count(df)
# Out:
# Уникальные значения: [ 4  1  3 12  8  2  5 15 10  9 11  7  6  0 13 14 17 19 16 21 18 20 -1 22
#  24 25 23]
# Количество значений, где год = -1: 141
# Удаление произведено: True

# %% [markdown]
# **В данных были обнаружены машины 2015 года, которые продались в 2014 году, такого быть не может, удалили их.**

# %%
x = df.groupby('year')['year'].count()
display (pd.DataFrame(x).T)

x.plot(kind='bar', figsize=(12, 4), rot=45)
plt.ylabel('Количество')
plt.xlabel('Год выпуска')
plt.title('Распределение количества проданных машин по году выпуска')
plt.show()
# Out:
# year  1989  1990  1991  1992  1993  1994  1995  1996  1997  1998  1999  2000  \
# year     1    31    52    86   132   272   475   541   966  1409  2138  3244
#
# year  2001  2002  2003   2004   2005   2006   2007   2008   2009   2010  \
# year  4681  7006  9364  12148  14998  18973  22130  23508  15533  19889
#
# year   2011   2012   2013   2014  2015
# year  37450  79522  77222  63492  7114

# %% [markdown]
# **Самое большое количество проданных машин - 2012 года выпуска, самое маленькое 1989 года - 1.**

# %% [markdown]
# #### Рассмотим данные столбца `make` (марка автомобиля):

# %%
df['make'].unique()
# Out:
# array(['Ford', 'Nissan', 'HUMMER', 'Lincoln', 'pontiac', 'Hyundai',
#        'Buick', 'Chevrolet', 'Honda', 'Acura', 'Cadillac', 'GMC', 'Saab',
#        'Dodge', 'Mercedes-Benz', 'Toyota', 'Volkswagen', 'BMW',
#        'Infiniti', 'Chrysler', 'Kia', 'Jaguar', 'Subaru', 'Jeep', 'Lexus',
#        'Scion', 'FIAT', 'Mazda', 'Volvo', 'Audi', 'MINI', 'Isuzu',
#        'Mitsubishi', 'smart', 'Pontiac', 'Porsche', 'subaru', 'ford',
#        'Land Rover', 'chrysler', 'Suzuki', 'Saturn', 'mazda', 'dodge',
#        'Ram', 'Oldsmobile', 'hyundai', 'Mercury', 'Bentley', 'toyota',
#        'lincoln', 'Fisker', 'chevrolet', 'nissan', 'honda', 'porsche',
#        'mitsubishi', 'lexus', 'bmw', 'Maserati', 'jeep', 'mercury',
#        'Tesla', 'landrover', 'vw', 'cadillac', 'land rover',
#        'Rolls-Royce', 'audi', 'Ferrari', 'buick', 'suzuki', 'Plymouth',
#        'oldsmobile', 'Lamborghini', 'mercedes', 'volkswagen', 'Geo',
#        'ford truck', 'gmc', 'Aston Martin', 'plymouth', 'Daewoo', 'kia',
#        'gmc truck', 'dodge tk', 'maserati', 'airstream'], dtype=object)

# %%
def upgrade_make(df, column):
    
    print('Количество уникальных значений до преобразования:', 
          df[column].nunique())
    print(60*'-')
    
    # переведем все в нижний регистр, избавимся от дубликатов
    df[column] = df[column].str.lower()
   
    # проверим марки машин, которые могут быть написаны по-разному, 
    # но являются одной и той же маркой
    unique_values = df[column].unique()

    for i_index, i in enumerate(unique_values):
        for j_index in range(i_index + 1, len(unique_values)):
            j = unique_values[j_index]
            if j in i or i in j:
                print(f'{i} содержится в {j}')
                df[column] = df[column].replace(j, i)
    
    # исправим некоторые компании в ручную:
    df[column] = df[column].replace({'landrover' : 'land rover', 
                                     'vw' : 'volkswagen',
                                     'airstream' : 'mercedes-benz'})
    
    print(60*'-')
    print('Количество уникальных значений после преобразования:', 
          df[column].nunique())
    
upgrade_make(df, 'make')

# проверка:
sorted(df['make'].unique())
# Out:
# Количество уникальных значений до преобразования: 88
# ------------------------------------------------------------
# ford содержится в ford truck
# gmc содержится в gmc truck
# dodge содержится в dodge tk
# mercedes-benz содержится в mercedes
# ------------------------------------------------------------
# Количество уникальных значений после преобразования: 52
# ['acura',
#  'aston martin',
#  'audi',
#  'bentley',
#  'bmw',
#  'buick',
#  'cadillac',
#  'chevrolet',
#  'chrysler',
#  'daewoo',
#  'dodge',
#  'ferrari',
#  'fiat',
#  'fisker',
#  'ford',
#  'geo',
#  'gmc',
#  'honda',
#  'hummer',
#  'hyundai',
#  'infiniti',
#  'isuzu',
#  'jaguar',
#  'jeep',
#  'kia',
#  'lamborghini',
#  'land rover',
#  'lexus',
#  'lincoln',
#  'maserati',
#  'mazda',
#  'mercedes-benz',
#  'mercury',
#  'mini',
#  'mitsubishi',
#  'nissan',
#  'oldsmobile',
#  'plymouth',
#  'pontiac',
#  'porsche',
#  'ram',
#  'rolls-royce',
#  'saab',
#  'saturn',
#  'scion',
#  'smart',
#  'subaru',
#  'suzuki',
#  'tesla',
#  'toyota',
#  'volkswagen',
#  'volvo']

# %% [markdown]
# Марка `airstream` модель `interstate` является партнером `mercedes-benz`, отнесем этот автомобиль к `mercedes-benz`

# %%
value_make = pd.DataFrame(df['make'].value_counts()).T
display (value_make)

value_make.T.head(10).plot(kind='bar', figsize=(12,4), rot=0,
title='Распределение наиболее часто продаваемых марок автомобилей')

value_make.T.tail(10).plot(kind='bar', figsize=(12,4), rot=0,
title='Распределение наиболее редко продаваемых марок автомобилей')
plt.show();
# Out:
#        ford  chevrolet  nissan  toyota  dodge  honda  hyundai    bmw    kia  \
# make  72826      46579   42204   31006  23768  20912    16905  15828  14145
#
#       chrysler  mercedes-benz  infiniti   jeep  volkswagen  lexus   gmc  \
# make     13490          13071     12027  11803        9579   9202  8117
#
#       mazda  cadillac  acura  audi  lincoln  subaru  buick   ram  pontiac  \
# make   6476      5724   4537  4504     4441    3917   3886  3567     3372
#
#       mitsubishi  volvo  mini  saturn  mercury  land rover  scion  porsche  \
# make        3315   2833  2435    2094     1485        1437   1307     1075
#
#       jaguar  suzuki  fiat  hummer  saab  smart  oldsmobile  isuzu  maserati  \
# make    1067     807   664     581   360    305         263    150       108
#
#       bentley  aston martin  tesla  ferrari  plymouth  geo  rolls-royce  \
# make       90            23     17       17        16   16           14
#
#       fisker  lamborghini  daewoo
# make       7            4       1

# %% [markdown]
# **Наиболее часто продаваемая марка автомобиля - `ford`, наиболее редко - `daewoo`.**

# %% [markdown]
# #### Рассмотим данные столбца `model` (модель автомобиля):

# %%
before_conversion = df['model'].nunique()

# %%
# отделение от модели всех слов, кроме первого
# и создание нового признака 'модификация':


# def modify_model(df):
#     return ' '.join(df.lower().split()[1:])

# удаление всех слов в модели, кроме первого:
def upgrade_model(df):
    return ' '.join(df.lower().split()[0:1])

#df['modify_model'] = df['model'].apply(modify_model)
df['model'] = df['model'].apply(upgrade_model)

# %% [markdown]
# Данными действиями мы избавились от явных дубликатов, а так же создали новый признак "модификация", в него входят такие параметры как

# %% [markdown]
# **Подумать**

# %%
# функция удаления строк, где количество моделей меньше 25:
def remove_model(df):
    df_cars = pd.pivot_table(df, index=['make', 'model'], values='year', aggfunc='count'). \
    sort_values(by=['make', 'model']).reset_index().rename(columns={'year' : 'count'})
    #display (df_cars)
    
    models_to_remove = df_cars.query('count <= 25')['model'].to_list()
    #print(sorted(models_to_remove))
    return df[~df['model'].isin(models_to_remove)]

df = remove_model(df)

print('Количество уникальных моделей до преобразования:', 
      before_conversion)
print(60*'-')
print('Количество уникальных моделей до преобразования:', 
      df['model'].nunique())
# Out:
# Количество уникальных моделей до преобразования: 924
# ------------------------------------------------------------
# Количество уникальных моделей до преобразования: 426

# %% [markdown]
# Данное действие позволило нам избавится от не правильно заполненных данных и строк где очень маленькое количество моделей.

# %% [markdown]
# #### Рассмотим данные столбца `body` (тип кузова транспортного средства):

# %%
df['body'].unique()
# Out:
# array(['suv', 'Sedan', 'sedan', nan, 'SUV', 'wagon', 'Minivan',
#        'Extended Cab', 'Regular Cab', 'Coupe', 'SuperCrew', 'Wagon',
#        'Crew Cab', 'SuperCab', 'Convertible', 'Hatchback', 'hatchback',
#        'G Coupe', 'G Convertible', 'coupe', 'Access Cab', 'G Sedan',
#        'regular cab', 'convertible', 'e-series van', 'minivan',
#        'supercrew', 'Quad Cab', 'tsx sport wagon', 'Van', 'g sedan',
#        'E-Series Van', 'CTS Coupe', 'Koup', 'King Cab', 'extended cab',
#        'double cab', 'Elantra Coupe', 'koup', 'access cab', 'Double Cab',
#        'crew cab', 'quad cab', 'g coupe', 'CrewMax Cab', 'supercab',
#        'g convertible', 'Genesis Coupe', 'van', 'G37 Coupe', 'club cab',
#        'Beetle Convertible', 'Mega Cab', 'regular-cab', 'Xtracab',
#        'cts coupe', 'genesis coupe', 'Club Cab', 'q60 coupe', 'mega cab',
#        'crewmax cab', 'Promaster Cargo Van', 'king cab', 'CTS-V Coupe',
#        'TSX Sport Wagon', 'CTS Wagon', 'G37 Convertible', 'Transit Van',
#        'Q60 Convertible', 'elantra coupe', 'beetle convertible',
#        'Q60 Coupe', 'promaster cargo van', 'transit van',
#        'g37 convertible', 'g37 coupe', 'Ram Van',
#        'granturismo convertible', 'GranTurismo Convertible', 'xtracab',
#        'cts-v coupe', 'q60 convertible', 'CTS-V Wagon'], dtype=object)

# %% [markdown]
# Присутствует большая разновидность cab, на данный момент заменим их на общее название.

# %%
count_unique_body = df['body'].nunique()
df['body'] = df['body'].str.lower().astype(str)

# изменим вариации типов кузова на стандартные названия
def upgrade_body(df):
    
    if 'convertible' in df:
        return 'convertible'
    elif 'coupe' in df:
        return 'coupe'
    elif 'van' in df:
        return 'van'
    elif 'koup' in df:
        return 'hatchback'
    elif 'sedan' in df:
        return 'sedan'
    elif 'wagon' in df:
        return 'wagon'
    elif 'cab' in df:
        return 'cab'
    else:
        return df

df['body'] = df['body'].apply(upgrade_body)

print('Количество уникальных кузовов до преобразования:',
      count_unique_body)
print(60*'-')
print('Количество уникальных кузовов после преобразования:',
      df['body'].nunique())

df['body'].unique()
# Out:
# Количество уникальных кузовов до преобразования: 82
# ------------------------------------------------------------
# Количество уникальных кузовов после преобразования: 10
# array(['suv', 'sedan', 'nan', 'wagon', 'van', 'cab', 'coupe', 'supercrew',
#        'convertible', 'hatchback'], dtype=object)

# %% [markdown]
# **Заполним пропуски:**

# %%
df['body'].value_counts()
# Out:
# sedan          185473
# suv            104734
# cab             25750
# hatchback       20322
# van             18347
# coupe           14033
# wagon           12146
# convertible      7186
# supercrew        6959
# nan              1354
# Name: body, dtype: int64

# %%
def fill_drop_body(df):
    
    # самый часто встречающийся кузов у моделей - мода
    body_dict = df.groupby('model')['body'].agg(pd.Series.mode)

    # замена пропущенных значений на моду
    df['body'] = df.apply(lambda x: body_dict[x['model']]
                          if x['body'] == 'nan'
                          else x['body'], axis=1)
    
    # удаление значений которые не заполнились
    df.drop(df[df['body'] == 'nan'].index, inplace=True)
    
fill_drop_body(df)

# проверка:
df['body'].value_counts()
# Out:
# sedan          185713
# suv            105237
# cab             25813
# hatchback       20330
# van             18497
# coupe           14056
# wagon           12353
# convertible      7204
# supercrew        6959
# Name: body, dtype: int64

# %%
df.groupby('body')['body'].count().sort_values(ascending=False). \
plot(kind='bar', rot=20, figsize=(9,4), title='Распределение типа кузова')
plt.ylabel('Количество');
plt.xlabel('Тип кузова');

# %% [markdown]
# **Больше всего проданных машин с типом кузова - `sedan`, меньше всего - `convertible` и `supercrew`**

# %% [markdown]
# #### Рассмотим данные столбца `transmission` (коробка передач):

# %% [markdown]
# **Заполним пропуски:**

# %%
df['transmission'].value_counts()
# Out:
# automatic    338518
# manual        12277
# Name: transmission, dtype: int64

# %%
df['transmission'].isna().sum()
# Out:
# 45367

# %%
def fill_drop_transmission(df):
    
    # самый часто встречающийся кузов у моделей - мода
    transmission_dict = df.groupby('model')['transmission'].agg(pd.Series.mode)

    # замена пропущенных значений на моду
    df['transmission'] = df.apply(lambda x: transmission_dict[x['model']]
                          if pd.isna(x['transmission'])
                          else x['transmission'], axis=1)
    
fill_drop_transmission(df)

# %%
df['transmission'].isna().sum()
# Out:
# 0

# %%
df.groupby('transmission')['transmission'].count(). \
plot(kind='bar', rot=0, figsize=(7,4), title='Распределение коробки передач')
plt.ylabel('Количество')
plt.xlabel('Тип коробки передач');

# %% [markdown]
# **Преобладающее большинство проданных машин имеют автоматическую коробку передач.**

# %% [markdown]
# #### Рассмотим данные столбца `state` (название штата):

# %%
df['state'].unique()
# Out:
# array(['md', 'mo', 'nj', 'tx', 'mi', 'nc', 'fl', 'oh', 'az', 'ca', 'ga',
#        'tn', 'in', 'pa', 'va', 'wi', 'co', 'ny', 'il', 'nv', 'mn', 'wa',
#        'sc', 'la', 'ne', 'ok', 'or', 'on', 'ma', 'ab', 'pr', 'hi', 'ut',
#        'qc', 'ms', 'nm', 'ns', 'al'], dtype=object)

# %% [markdown]
# **Название штатов в сокращенном виде, дубликаты отсутствуют.**

# %% [markdown]
# #### Рассмотим данные столбца `condition` (cостояние автомобилей на момент аукциона):

# %%
df['condition'].unique()
# Out:
# array([4.2, 3.5, 2.2, 2.8, 2. , 2.5, 3.4, 4.8, 1.9, 1. , 2.7, 3.6, 2.9,
#        4.1, 2.6, 2.1, 3. , 4.9, 4.7, 4. , 3.3, 3.8, 3.7, 4.5, 4.6, 5. ,
#        4.3, 2.4, 2.3, 3.9, 3.1, 3.2, 4.4, 1.4, 1.5, 1.7, 1.2, 1.3, 1.6,
#        1.8, 1.1])

# %%
condition_count = df.groupby('condition')['condition'].count(). \
plot(kind='bar', figsize=(12, 4), title='Распределение количества оценок',
    rot=45);
plt.ylabel('Количество')
plt.xlabel('Оценка автомобиля');

# %%
df['condition'].describe()
# Out:
# count    396162.000000
# mean          3.434292
# std           0.945711
# min           1.000000
# 25%           2.700000
# 50%           3.600000
# 75%           4.200000
# max           5.000000
# Name: condition, dtype: float64

# %% [markdown]
# Минимальная оценка автомобиля - 1, максимальная - 5, состояние от плохо до хорошего. </br>
# Медианное значение оценки - 3.6.

# %% [markdown]
# #### Рассмотим данные столбца `odometer` (расстояние, пройденное автомобилем с момента выпуска):

# %%
df['odometer'].describe()
# Out:
# count    396162.000000
# mean      66126.010753
# std       52225.645286
# min           1.000000
# 25%       27598.000000
# 50%       49778.500000
# 75%       95671.750000
# max      999999.000000
# Name: odometer, dtype: float64

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='odometer', y='year', data=df, orient='h')
plt.xlabel('Пробег')
plt.ylabel('Год выпуска')
plt.title('Boxplot пробега для каждого года')
plt.tight_layout()
plt.show()

# %% [markdown]
# Наблюдаем выбросы в данных, пробег - 999999, явно ошибка заполнения. </br>
# Учитывая факт, что в 1 миле ~ 1.6 км, большинство проданных машин 2011 - 2015 года выпуска, а средний пробег у американских машин = 14.300 миль в год, удалим все значения, где пробег больше 190000.</br>
# Так же удалим все строки, где пробег меньше 50 км. Такой пробег у б/у машин маловереятен.

# %%
display(df.query('odometer > 190000')['year'].count())
display(df.query('odometer < 50')['year'].count())
print(f'Размер: {df.shape}')

def drop_odometr(df):
    df.drop(df[(df['odometer'] > 190000) | 
           (df['odometer'] < 50)].index, inplace=True)

drop_odometr(df)

# проверка:
print(f'Проверка: {396296 - 10374 - 1092 == df.shape[0]}')
# Out:
# 10374
# 1091
# Размер: (396162, 17)
# Проверка: False

# %%
df['odometer'].describe()
# Out:
# count    384697.000000
# mean      61946.071235
# std       44279.095015
# min          50.000000
# 25%       27213.000000
# 50%       48258.000000
# 75%       91581.000000
# max      189999.000000
# Name: odometer, dtype: float64

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='odometer', y='year', data=df, orient='h')
plt.xlabel('Пробег')
plt.ylabel('Год выпуска')
plt.title('Boxplot пробега для каждого года')
plt.tight_layout()
plt.show()

# %% [markdown]
# # ПОДУМАТЬ КАКИЕ УДАЛИТЬ

# %%
#df.query('odometer > 80000 & year == 2012 ').count()

# %% [markdown]
# #### Рассмотим данные столбца `color` (цвет кузова автомобиля):

# %%
color_count = pd.DataFrame(df['color'].value_counts())
display(color_count.T)

color_count['percent'] = (color_count['color'] / 
                          (color_count['color'].sum())) * 100

color_count['percent'].plot(kind='bar', figsize=(12, 4), 
                            title='Распределение цветов кузова в процентах',
                            rot=45);
plt.ylabel('Процент')
plt.xlabel('Цвет');
# Out:
#        black  white   gray  silver   blue    red  unknown  green  gold  \
# color  76544  72585  58186   57656  34604  30190    18901   7075  7011
#
#        burgundy  beige  brown  orange  purple  off-white  yellow  charcoal  \
# color      6164   5955   4818    1432    1103       1075     863       342
#
#        turquoise  pink  lime
# color        150    30    13

# %% [markdown]
# **Самые популярные цвета кузова - черный и белый, самые редкие - розовый и лайм.**

# %% [markdown]
# #### Рассмотим данные столбца `interior` (цвет салона автомобиля):

# %%
color_count = pd.DataFrame(df['interior'].value_counts())
display(color_count.T)

color_count['percent'] = (color_count['interior'] / 
                          (color_count['interior'].sum())) * 100

color_count['percent'].plot(kind='bar', figsize=(12, 4), 
                            title='Распределение цветов салона в процентах',
                            rot=45);
plt.ylabel('Процент')
plt.ylabel('Цвет');
# Out:
#            black    gray  beige    tan  unknown  brown  red  silver  blue  \
# interior  173548  122681  41537  29608     7993   5689  868     725   649
#
#           off-white  purple  gold  white  green  burgundy  orange  yellow
# interior        335     241   233    196    159       131      91      13

# %% [markdown]
# **Самый популярный цвет салона - черный, самый редкий - желтый.**

# %% [markdown]
# #### Рассмотим данные столбца `sellingprice` (цена, по которой автомобиль был продан на аукционе):

# %%
df['sellingprice'].describe()
# Out:
# count    384697.000000
# mean      13950.545382
# std        9314.129306
# min         100.000000
# 25%        7900.000000
# 50%       12500.000000
# 75%       18300.000000
# max      230000.000000
# Name: sellingprice, dtype: float64

# %%
# сетка для графика
fig, axs = plt.subplots(1, 2, figsize=(12, 4))

# левая гистограмма 
axs[0].hist(df['sellingprice'], bins=20, range=(0, 500), color='blue')
axs[0].set_title('Распределение автомобилей по стоимости в диапазоне 0-500 $')
axs[0].set_xlabel('Цена')
axs[0].set_ylabel('Количество')

# правая гистограмма 
axs[1].hist(df['sellingprice'], bins=20, range=(200000, 230000), color='orange')
axs[1].set_title('Распределение автомобилей по стоимости в диапазоне 200000 -230000 $')
axs[1].set_xlabel('Цена')

plt.tight_layout()
plt.show()

# %% [markdown]
# **На американских сайтах по продаже автомобилей, минимальная стоимость автомобиля составляет 500 долларов, можно  предположить, что это не правильно введенные данные. `sellingprice` является целевым признаком и в тестовых данных он отсутвует, поэтому удалять мы эти сроки не будем.**

# %%
plt.figure(figsize=(10, 4))
plt.scatter(y=df['sellingprice'], x=df['year'])
plt.title('Распределение стоимости автомобиля по годам')
plt.xlabel('Год')
plt.ylabel('Стоимость');

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='sellingprice', y='year', data=df, orient='h')
plt.xlabel('Год выпуска')
plt.ylabel('Стоиомость')
plt.title('Boxplot стоимости для каждого года')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Стоимость автомобиля зависит от года выпуска, чем позже выпуск, тем больше его стоимость, так же на графике наблюдаем выбросы.**

# %% [markdown]
# ### Создание новых признаков

# %%
dict_country =  {'2' : 'Canada', '3' : 'Mexico', '5' : 'United States',
                     '1' : 'United States', 'k' : 'South Korea', 'j' : 'Japan',
                     'y' : 'Finland', '4' : 'United States', 'w' : 'Germany',
                     's' : 'United Kingdom', '9' : 'Brazil', 'z' : 'Italy',
                     'n' : 'Serbia', 'm' : 'India', 't' : 'Switzerland',
                     '6' : 'Australia', 'v': 'France'}

def new_columns(df):

    # разделим признак "количество лет" на 3 группы (новая, средняя, старая):
    df['year_category'] = pd.cut(df['year_count'], 
                             bins=[-1, 4, 8, 13, 26],
                             labels=[1, 2, 3, 4])

    # разделим признак "пробег" на 5 групп:
    df['odometer_category'] = pd.cut(df['odometer'], 
                                bins=[0, 15000, 38000, 69000,
                                      115000, 190000], labels=[1, 2, 3, 4, 5])
    # страна производства автомобиля:
    df['country_of_origin'] = df['vin'].apply(lambda x: x[0:1]).replace(dict_country)

new_columns(df)

# %%
df.sample(15)
# Out:
#         year        make      model             trim         body  \
# 318538  2004   chevrolet      tahoe               LS          suv
# 277093  1998        ford    mustang             Base        coupe
# 38456   2007   chevrolet  avalanche               LT          cab
# 255093  2014   chevrolet     impala         LT Fleet        sedan
# 6805    2012   chevrolet       volt             Base    hatchback
# 169905  2011        ford      f-350               XL          cab
# 364542  2011      nissan      versa            1.8 S    hatchback
# 134746  2013  volkswagen        eos  Executive SULEV  convertible
# 214962  2008   chevrolet  avalanche               LS          cab
# 190629  2008      toyota       rav4            Sport          suv
# 74830   2013      toyota       rav4              XLE          suv
# 403749  2006        ford      f-250           Lariat          cab
# 57039   2013   chevrolet     impala              LTZ        sedan
# 313357  2012        ford     fusion              SEL        sedan
# 397389  2008    chrysler      aspen          Limited          suv
#
#        transmission                vin state  condition  odometer    color  \
# 318538    automatic  1gnec13z84r319720    fl        2.0  173606.0    black
# 277093    automatic  1fafp4043wf185673    fl        1.9  137936.0     blue
# 38456     automatic  3gnfk12377g114057    wa        2.6  150245.0    black
# 255093    automatic  2g1wb5e36e1108700    sc        4.6   16843.0   silver
# 6805      automatic  1g1ra6e41cu107583    az        2.9   61711.0   silver
# 169905    automatic  1ft8w3at9bea16828    fl        1.9  159771.0    white
# 364542    automatic  3n1bc1cp1bl414413    fl        2.9   79240.0     gray
# 134746    automatic  wvwfw8ah7dv007516    oh        2.6   26959.0  unknown
# 214962    automatic  3gnfk12328g260688    fl        3.8   85300.0      red
# 190629    automatic  jtmbd32vx86079080    nj        1.9   68395.0     gray
# 74830     automatic  2t3rfrev8dw057952    wi        3.8   37530.0    white
# 403749    automatic  1ftsw21p76ec40317    tx        1.9  143389.0    brown
# 57039     automatic  2g1wc5e37d1209062    sc        4.0   46537.0    black
# 313357    automatic  3fahp0ja1cr393040    mo        2.5   27588.0  unknown
# 397389    automatic  1a8hw582x8f134729    mo        2.8   59640.0     gray
#
#        interior                                         seller  sellingprice  \
# 318538     gray                             santander consumer          2000
# 277093    black                             coggin deland ford          1200
# 38456     black                                puyallup nissan          7800
# 255093    black                    king cadillac buick gmc inc         14600
# 6805      black          ge fleet services for itself/servicer         13100
# 169905     gray                           meridian remarketing          9600
# 364542    black        remarketing by ge/summit financial corp          5000
# 134746    black                                      vw credit         23200
# 214962     gray              remarketing by ge/sw1 remarketing         16900
# 190629    black                      toyota financial services          9100
# 74830      gray                          midwestern wheels inc         20800
# 403749    beige  remarketing by ge/general auto acceptance llc         12000
# 57039      gray                 enterprise veh exchange/rental         12500
# 313357    black               ford motor credit company,llc pd          9100
# 397389     gray                            exeter finance corp         14800
#
#                         saledate  year_sale  year_count year_category  \
# 318538 2015-01-21 17:40:00+00:00       2015          11             3
# 277093 2015-01-06 10:00:00+00:00       2015          17             4
# 38456  2015-02-17 20:30:00+00:00       2015           8             2
# 255093 2015-03-04 18:00:00+00:00       2015           1             1
# 6805   2014-12-18 03:00:00+00:00       2014           2             1
# 169905 2015-06-04 01:00:00+00:00       2015           4             1
# 364542 2015-02-03 17:00:00+00:00       2015           4             1
# 134746 2015-01-13 01:30:00+00:00       2015           2             1
# 214962 2015-02-09 19:05:00+00:00       2015           7             2
# 190629 2015-05-12 19:30:00+00:00       2015           7             2
# 74830  2015-06-02 20:00:00+00:00       2015           2             1
# 403749 2015-05-20 21:00:00+00:00       2015           9             3
# 57039  2015-01-07 17:15:00+00:00       2015           2             1
# 313357 2015-06-08 20:30:00+00:00       2015           3             1
# 397389 2015-02-17 18:30:00+00:00       2015           7             2
#
#        odometer_category country_of_origin
# 318538                 5     United States
# 277093                 5     United States
# 38456                  5            Mexico
# 255093                 2            Canada
# 6805                   3     United States
# 169905                 5     United States
# 364542                 4            Mexico
# 134746                 2           Germany
# 214962                 4            Mexico
# 190629                 3             Japan
# 74830                  2            Canada
# 403749                 5     United States
# 57039                  3            Canada
# 313357                 2            Mexico
# 397389                 3     United States

# %% [markdown]
# ### Исследовательский анализ данных

# %%
df.head(2)
# Out:
#    year  make   model trim   body transmission                vin state  \
# 0  2011  ford    edge  SEL    suv    automatic  2fmdk3jc4bba41556    md
# 1  2014  ford  fusion   SE  sedan    automatic  3fa6p0h75er208976    mo
#
#    condition  odometer  color interior                 seller  sellingprice  \
# 0        4.2  111041.0  black    black     santander consumer         12500
# 1        3.5   31034.0  black    black  ars/avis budget group         14500
#
#                    saledate  year_sale  year_count year_category  \
# 0 2015-06-01 19:30:00+00:00       2015           4             1
# 1 2015-02-24 18:00:00+00:00       2015           1             1
#
#   odometer_category country_of_origin
# 0                 4            Canada
# 1                 2            Mexico

# %% [markdown]
# ### Матрица корреляции

# %%
phik = df.drop(['year', 'vin', 'saledate','state', 'seller', 'year_sale' ], axis=1).phik_matrix();
sns.set(rc={'figure.figsize':(14, 14)});
sns.heatmap(phik, annot=True, cmap='coolwarm', fmt='.2f');
# Out:
# interval columns not set, guessing: ['condition', 'odometer', 'sellingprice', 'year_count']

# %% [markdown]
# По матрице корреляции, можем наблюдать, наличие мультиколлинеарности признаков. Присутсвие этих факторов не повлияют на обучение наших моделей, поэтому удалять мы их не будем.

# %% [markdown]
# ### Оптимизация используемой памяти

# %%
# новый DF для сравнения результатов:
converted_obj = pd.DataFrame()

# проверяем, если уникальных значений в столбцах 'object' менее 50%, 
# то оптимизируем их в 'category'%:
s = []
for col in df.columns:
    num_unique_values = len(df[col].unique())
    num_total_values = len(df[col])
    if num_unique_values / num_total_values < 0.5 and df[col].dtype == 'O':
        converted_obj.loc[:,col] = df[col].astype('category')
        s.append(col)
    else:
        converted_obj.loc[:,col] = df[col]
print('Признаки, которые рекомендуется перевести в тип `category`:', s)
# Out:
# Признаки, которые рекомендуется перевести в тип `category`: ['make', 'model', 'trim', 'body', 'transmission', 'state', 'color', 'interior', 'seller', 'country_of_origin']

# %%
def memory_usage_optimization(df):

    print(f'До оптимизации столбцов: \
    {round(df.memory_usage(deep=True).sum() / (1024 ** 2), 2)} MB')

    # удаление не нужных признаков:
    df.drop(df[['year', 'vin', 'state', 'seller', 'saledate', 'year_sale']], 
            axis=1, inplace=True)
    
    # изменение типов данных:
    col_types = {'make' : 'category', 'model' : 'category', 
                 'trim' : 'category', 'body' : 'category', 
                 'transmission' : 'category', 'color' :'category', 
                 'interior' : 'category', 'country_of_origin' : 'category',
                 'condition' : 'float32', 'odometer' : 'float32',
                 'sellingprice' : 'int32', 'year_count' : 'int32',
                 'year_category' : 'int32', 'odometer_category' : 'int32'}

    df = df.astype(col_types)

    print(f'После оптимизации столбцов: \
    {round(df.memory_usage(deep=True).sum() / (1024 ** 2), 2)} MB')
    
    return df

df = memory_usage_optimization(df)
# Out:
# До оптимизации столбцов:     287.73 MB
# После оптимизации столбцов:     15.62 MB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 384697 entries, 0 to 440235
# Data columns (total 14 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   make               384697 non-null  category
#  1   model              384697 non-null  category
#  2   trim               384697 non-null  category
#  3   body               384697 non-null  category
#  4   transmission       384697 non-null  category
#  5   condition          384697 non-null  float32
#  6   odometer           384697 non-null  float32
#  7   color              384697 non-null  category
#  8   interior           384697 non-null  category
#  9   sellingprice       384697 non-null  int32
#  10  year_count         384697 non-null  int32
#  11  year_category      384697 non-null  int32
#  12  odometer_category  384697 non-null  int32
#  13  country_of_origin  384697 non-null  category
# dtypes: category(8), float32(2), int32(4)
# memory usage: 15.5 MB

# %%
df.head(2)
# Out:
#    make   model trim   body transmission  condition  odometer  color interior  \
# 0  ford    edge  SEL    suv    automatic        4.2  111041.0  black    black
# 1  ford  fusion   SE  sedan    automatic        3.5   31034.0  black    black
#
#    sellingprice  year_count  year_category  odometer_category  \
# 0         12500           4              1                  4
# 1         14500           1              1                  2
#
#   country_of_origin
# 0            Canada
# 1            Mexico

# %% [markdown]
# ### Обучение моделей

# %%
category_columns = df.select_dtypes(include='category').columns.to_list()

# выделим признаки
features = df.drop(['sellingprice'], axis =1)
target = df['sellingprice']

# %% [markdown]
# #### Построим модель `CatBoostRegressor`:

# %%
#укажем категориальные переменные
cat_features = category_columns

parameters = {'learning_rate': np.arange(0.01, 0.1, 0.01),
             'max_depth' : [2, 5, 8]}

model = CatBoostRegressor()

grie_search_cbr = GridSearchCV(model, parameters, cv=5,
                            scoring='MAPE')


grie_search_cbr.fit(features, target)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Applications/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_scorer.py:415, in get_scorer(scoring)
#     414 try:
# --> 415     scorer = copy.deepcopy(_SCORERS[scoring])
#     416 except KeyError:
#
# KeyError: 'MAPE'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Input In [82], in <cell line: 13>()
#       7 model = CatBoostRegressor()
#       9 grie_search_cbr = GridSearchCV(model, parameters, cv=5,
#      10                             scoring='MAPE')
# ---> 13 grie_search_cbr.fit(features, target)
#
# File /Applications/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py:777, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     775     scorers = self.scoring
#     776 elif self.scoring is None or isinstance(self.scoring, str):
# --> 777     scorers = check_scoring(self.estimator, self.scoring)
#     778 else:
#     779     scorers = _check_multimetric_scoring(self.estimator, self.scoring)
#
# File /Applications/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_scorer.py:464, in check_scoring(estimator, scoring, allow_none)
#     459     raise TypeError(
#     460         "estimator should be an estimator implementing 'fit' method, %r was passed"
#     461         % estimator
#     462     )
#     463 if isinstance(scoring, str):
# --> 464     return get_scorer(scoring)
#     465 elif callable(scoring):
#     466     # Heuristic to ensure user has not passed a metric
#     467     module = getattr(scoring, "__module__", None)
#
# File /Applications/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_scorer.py:417, in get_scorer(scoring)
#     415         scorer = copy.deepcopy(_SCORERS[scoring])
#     416     except KeyError:
# --> 417         raise ValueError(
#     418             "%r is not a valid scoring value. "
#     419             "Use sklearn.metrics.get_scorer_names() "
#     420             "to get valid options." % scoring
#     421         )
#     422 else:
#     423     scorer = scoring
#
# ValueError: 'MAPE' is not a valid scoring value. Use sklearn.metrics.get_scorer_names() to get valid options.

# %%
best_params_cbr = qcv_catboost.best_params_
best_score_cbr = qcv_catboost.best_score_

print(best_params_cbr)
print(85*'-')
print(f'RMSE: {np.round(rmse_catboost, 3)}')
print(85*'-')

# %% [markdown]
# audi	allroad		35
# 24	audi	allroad	quattro	24 - удалить
# bmw	6	series	 - удалить series слово
# bmw	750i		750i	21
# 318	bmw	750i		xdr 750i xdriv	3
# 319	bmw	750li		750li	14
# 320	bmw	750li		xdr 750li xdr	8
# 321	bmw	750lxi	                          ---- изменить на 7
# chevrolet	silverado	1500 classic	157 удалить classic
# chevrolet	silverado	2500hd classic
# chrysler	town	and country - удалить country
# dodge	grand	caravan	 - добавить caravan и удалить
# ford	f-150	heritage	 -удалить
# ДОБАВИТЬ -
# gmc	sierra	1500 classic - удалить classic
# xj-series		125 - удалить series
# jaguar	xk-series
# land rover	discovery	series ii	 - удалить
# land rover	range	rover	303
# 482	land rover	range	rover evoque	115
# 483	land rover	range	rover sport	579
# exus	is	f	28 - удалить
# mercedes-benz
#
# suzuki	xl-7		65
# suzuki	xl7		115
# toyota	land	cruiser
# volkswagen	new	beetle
# volkswagen	touareg	2
# volkswagen	gli		56 ?????
# volkswagen	gti		340 ?????
# volkswagen	touareg	2	33
#
# 59	volvo	xc		22 - посмотреть что там/удалить
